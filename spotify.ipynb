# %% [markdown]
# # Instructions:
#
#  - Go to https://developer.spotify.com/dashboard/
#  - On your Dashboard click CREATE A CLIENT ID.
#  - Enter Application Name and Application Description and then click CREATE. Your application is registered, and the app view opens.
#  - On the app view, click Edit Settings to view and update your app settings.
#
#  - In Redirect URIs enter `http://localhost:8888/callback` which you want to whitelist with Spotify. This URI enables the Spotify authentication service to automatically re-launch your app every time the user logs in.
#
#
#  **Fill in your username, client-id and client-secret below from your created app.**

# %%
import spotipy
import spotipy.util as util

USERNAME = "username"
CLIENT_ID = "client-id"
CLIENT_SECRET = "cleint-secret"
username = USERNAME
token = util.prompt_for_user_token(USERNAME, scope="user-read-private", CLIENT_ID , CLIENT_SECRET ,redirect_uri='http://localhost:8888/callback')
sp = spotipy.Spotify(auth=token)

# %%
fivesos = sp.albums(albums=["2LkWHNNHgD6BRNeZI2SL1L"],)

# %%
fivesos["albums"][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'copyrights', 'external_ids', 'external_urls', 'genres', 'href', 'id', 'images', 'label', 'name', 'popularity', 'release_date', 'release_date_precision', 'tracks', 'type', 'uri'])

# %%
fivesos["albums"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#   'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#   'id': '5Rl15oVamLq7FbSb0NNBNy',
#   'name': '5 Seconds of Summer',
#   'type': 'artist',
#   'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}]

# %%
fivesos["albums"][0]["tracks"]
# Out:
# {'href': 'https://api.spotify.com/v1/albums/2LkWHNNHgD6BRNeZI2SL1L/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Rl15oVamLq7FbSb0NNBNy'},
#      'href': 'https://api.spotify.com/v1/artists/5Rl15oVamLq7FbSb0NNBNy',
#      'id': '5Rl15oVamLq7FbSb0NNBNy',
#      'name': '5 Seconds of Summer',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Rl15oVamLq7FbSb0NNBNy'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
# ...

# %%
results = sp.search(q='passenger', limit=20)
for i, t in enumerate(results['tracks']['items']):
    print (' ', i, t['name'])
# Out:
#   0 Let Her Go
#   1 Passenger Side
#   2 Passenger
#   3 Passenger
#   4 The Passenger
#   5 Passenger
#   6 The Passenger
#   7 Simple Song
#   8 Hell Or High Water
#   9 Anywhere
#   10 Simple Song
#   11 Passenger Seat
#   12 Passenger Seat (feat. Kora)
#   13 Passenger Seat
#   14 The Passenger
#   15 Runaway
#   16 Let Her Go - Acoustic
#   17 Shape of Love (feat. Boy & Bear)
#   18 Madison
#   19 Why Can't I Change

# %%
if token:
    sp = spotipy.Spotify(auth=token)
    playlists = sp.user_playlists(username)
    for playlist in playlists['items']:
#         if playlist['owner']['id'] == username:
        print()
        print(playlist['name'])
        print('  total tracks', playlist['tracks']['total'])
        results = sp.user_playlist(username, playlist['id'], fields="tracks,next")
        tracks = results['tracks']
        show_tracks(tracks)
        while tracks['next']:
            tracks = sp.next(tracks)
            show_tracks(tracks)
else:
    print("Can't get token for", username)
# Out:
# where is it you wanna go?
#   total tracks 47
#    0                  Louis The Child Go
#    1                      Frank Ocean Lost
#    2                     Harry Styles Ever Since New York
#    3                           Khalid Location
#    4       Kyle Dixon & Michael Stein The First Lie
#    5                    Calvin Harris Slide
#    6                      Miley Cyrus Malibu
#    7                     Harry Styles Sign of the Times
#    8                     Selena Gomez Bad Liar
#    9                     Selena Gomez Wolves
#    10                         RICEWINE Waterfall
#    11                         RICEWINE Dreams / Nightmares
#    12                            Haute Shut Me Down
#    13                           Rixton We All Want The Same Thing
#    14                            Logic 1-800-273-8255
#    15                  Imagine Dragons Thunder
#    16                    Local Natives Wide Eyes
#    17                        Col3trane Penelope
# ...

# %%
sp.user_playlists(username)["items"]
# Out:
# [{'collaborative': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/user/rosejack-us/playlist/5dIZWQMVQI6YbABsLt0706'},
#   'href': 'https://api.spotify.com/v1/users/rosejack-us/playlists/5dIZWQMVQI6YbABsLt0706',
#   'id': '5dIZWQMVQI6YbABsLt0706',
#   'images': [{'height': None,
#     'url': 'https://pl.scdn.co/images/pl/default/3707ff8a8b9dac097259716577519f486757e87d',
#     'width': None}],
#   'name': 'where is it you wanna go?',
#   'owner': {'display_name': None,
#    'external_urls': {'spotify': 'https://open.spotify.com/user/rosejack-us'},
#    'href': 'https://api.spotify.com/v1/users/rosejack-us',
#    'id': 'rosejack-us',
#    'type': 'user',
#    'uri': 'spotify:user:rosejack-us'},
#   'primary_color': None,
#   'public': True,
#   'snapshot_id': '6j5TTkGgP7rcHGrsTh9uERCfWsy7lc4MFsWMvoU9QPCMoP2azYst4jl8X/AJMJQK',
#   'tracks': {'href': 'https://api.spotify.com/v1/users/rosejack-us/playlists/5dIZWQMVQI6YbABsLt0706/tracks',
#    'total': 47},
# ...

# %% [markdown]
# # References
#
# https://developer.spotify.com/documentation/general/guides/app-settings/
